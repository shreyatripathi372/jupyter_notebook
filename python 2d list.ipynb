# %%
fruits=["aple","orange","banana","cocnut"]
vegetables=["celery","catrrots","potatoes"]
meat=["chicekn","fish","turkey"]
groceries=[fruits,vegetables,meat]
print(groceries[2][1])
# Out:
# fish

# %%
groceries=[["aple","orange","banana","coconut"],
           ["celery","carrots","potatoes"],
           ["chicken","fish","turkey"]]
for collection in groceries:
    for food in collection:
        print(food, end=" ")
    print()
# Out:
# aple orange banana coconut
# celery carrots potatoes
# chicken fish turkey

# %%
num_pad=((1,2,3),
         (4,5,6),
         (7,8,9),
         ("*",0,"#"))
for row in num_pad:
    for num in row:
        print(num, end=" ")
    print()
# Out:
# 1 2 3
# 4 5 6
# 7 8 9
# * 0 #
