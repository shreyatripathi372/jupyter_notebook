# %%
l = [3,5,23,9]

# %%
l[0]=4

# %%
l
# Out:
# [4, 5, 23, 9]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 23, 9, 9]

# %%
l2 =[5,7]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 23, 9, 9, 5, 7]

# %%
l.insert(1,200)

# %%
l
# Out:
# [4, 200, 5, 23, 9, 9, 5, 7]

# %%
l.pop(4)
# Out:
# 9
