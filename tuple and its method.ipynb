# %%
e=()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
t=(5,64,23,23)

# %%
t
# Out:
# (5, 64, 23, 23)

# %%
len(t)
# Out:
# 4

# %%
t[0]
# Out:
# 5

# %%
print(t[1])
# Out:
# 64

# %%
#packing 
person =("alice",25,"engineer")
#unpacking 
name,age,profession=person

# %%
name
# Out:
# 'alice'

# %%
age
# Out:
# 25

# %%
profession
# Out:
# 'engineer'
