# %%
class Car:
    def__init__(self,model,year,color,for_sale):
    self.model=model
    self.year=year
    self.color=color
    self.for_sale=for_sale
car1=car("MUSTANG",2024,"RED",FALSE)
car2=car("corvette",2025,"blue",true)
print(car1.model)
print(car1.year)
print(car1.color)
print(car1.for_sale)
