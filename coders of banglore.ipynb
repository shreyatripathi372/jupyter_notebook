# %%
#coders of banglore 
#data collection 
you hire vijyalakshmi iyer and sam cahndra who are from hebbal and hsr respectively

# %%
with open("file.txt", encoding = 'utf-8') as f:
    data = f.read()

# %%
data

# %%
chunks = data.split("\n\n")

# %%
chunks[0]

# %%
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk
