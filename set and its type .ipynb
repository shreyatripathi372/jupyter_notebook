# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b=set()

# %%
type(b)
# Out:
# set

# %%
s={4,3,6,2,66,4}

# %%
s
# Out:
# {2, 3, 4, 6, 66}

# %%
#creating a set from a list
unique_numbers=set({1,2,2,4,4,5})
print(unique_numbers)
# Out:
# {1, 2, 4, 5}
