# %%
doubles =[]
for x in range(1,11):
    doubles.append(x*2)
print(doubles)

# %%
doubles =[x*2 for x in range(1,11)]
print(doubles)

# %%
triple=[y*3 for y in range(1,11)]
print(triple)

# %%
squares=[z*z for z in range(1,11)]
print(squares)
fruits=[

# %%
fruits=["apple","orange","banana","coconut"]
fruits_char=[fruit[0] for fruit in fruits]
print(fruits_char)

# %%
grades=[85,42,79,90,56,61,30]
passing_grades =[grades for grade in grades if grade>=60]
print(passing_grades)

# %%
def day_of_week(day):
    if day==1:
        return "it is sunday"
    elif day==2:
        return
