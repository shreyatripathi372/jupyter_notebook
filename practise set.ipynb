# %%
def cal_sum(lst):
    total = 0
    for i in lst:
        total = total + i
    return total

print(cal_sum([8, 2, 3, 0, 7]))

# %%
def reverse_string(s):
    return s[ ::-1]
print(reverse_string("1234abcd"))

# %%
def cal_fact(n):
   fact =1
   for i in range(1,n+1):
       fact = fact *i
   return fact

print(cal_fact(6))

# %%
def count_str(s):
    return len(s)
print(count_str("Abcdef"))

# %%
def even_str(nums):
    evens = []
    for i in nums:
        if i % 2 == 0:
            even.append(i)
    return evens

print(even_str([1, 3, 5, 8, 11, 14]))

# %%
def eve
